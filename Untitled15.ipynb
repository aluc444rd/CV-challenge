# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 903.1/903.1 kB 3.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Get Started

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="HWGasZldqdiXGdVDPDsM")
project = rf.workspace("naima-el-menani").project("moroccan-license-plate-detection")
version = project.version(4)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to moroccan-license-plate-detection-4 in yolov11:: 100%|██████████| 5128/5128 [00:01<00:00, 3458.50it/s]

# %%
dataset.location
# Out:
# '/content/moroccan-license-plate-detection-4'

# %%
# !yolo task=detect mode=train data=/content/moroccan-license-plate-detection-4/data.yaml model=yolo11s.pt epochs=100 batch=8 imgsz=512 amp=True
# Out:
# ...
# 100% 18.4M/18.4M [00:00<00:00, 198MB/s]
# Ultralytics 8.3.54 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import Image

Image("/content/runs/detect/train/labels.jpg")

# %%
Image("/content/runs/detect/train/confusion_matrix.png")

# %%
Image("/content/runs/detect/train/results.png")

# %%
Image("/content/runs/detect/train/val_batch0_pred.jpg")

# %%
Image("/content/runs/detect/train/val_batch1_pred.jpg")

# %%
Image("/content/runs/detect/train/val_batch2_pred.jpg")

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model='/content/runs/detect/train/weights/best.pt' source='/content/Super cars in Morocco Marrakech.mp4'
# Out:
# Ultralytics 8.3.54 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11s summary (fused): 238 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#
# video 1/1 (frame 1/969) /content/Super cars in Morocco Marrakech.mp4: 512x320 1 LP, 47.8ms
# video 1/1 (frame 2/969) /content/Super cars in Morocco Marrakech.mp4: 512x320 1 LP, 9.2ms
# video 1/1 (frame 3/969) /content/Super cars in Morocco Marrakech.mp4: 512x320 1 LP, 9.1ms
# video 1/1 (frame 4/969) /content/Super cars in Morocco Marrakech.mp4: 512x320 1 LP, 9.1ms
# video 1/1 (frame 5/969) /content/Super cars in Morocco Marrakech.mp4: 512x320 1 LP, 9.1ms
# video 1/1 (frame 6/969) /content/Super cars in Morocco Marrakech.mp4: 512x320 1 LP, 9.1ms
# video 1/1 (frame 7/969) /content/Super cars in Morocco Marrakech.mp4: 512x320 1 LP, 9.1ms
# video 1/1 (frame 8/969) /content/Super cars in Morocco Marrakech.mp4: 512x320 1 LP, 9.1ms
# ...
